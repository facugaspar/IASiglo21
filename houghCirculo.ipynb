# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
img = cv.imread('Circulos.png')

plt.imshow(img)
plt.show()

# %%
src = cv.medianBlur(img, 5)
src = cv.cvtColor(src, cv.COLOR_BGR2GRAY)

plt.imshow(src)
plt.show()

# %%
circles = cv.HoughCircles(src, cv.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=0, maxRadius=0)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # dibujar circulo 
    cv.circle(img, (i[0], i[1]), i[2], (0,255,0), 2)
    # dibujar centro
    cv.circle(img, (i[0], i[1]), 2, (0,0,255), 3)
# Out:
# Centro (420, 438), radio = 401
# Centro (462, 406), radio = 454
# Centro (376, 478), radio = 458
# Centro (386, 402), radio = 450
# Centro (458, 478), radio = 454
# Centro (494, 366), radio = 505

# %%
cv.imshow('detected circles', img)

plt.imshow(img)
plt.show()

# %%
cv.imshow('Detector de Lineas', img)

plt.imshow(img)
plt.show()
